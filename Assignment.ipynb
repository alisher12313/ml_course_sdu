# %%
import pandas as pd

# %%
df = pd.read_csv('data/fifa-21-player-datasets.csv')
print(df.head())
print(df.columns)
print(df.shape)
# Out:
#                 name  age  height_cm  weight_kg nationality  \
# 0           L. Messi   33        170         72   Argentina
# 1  Cristiano Ronaldo   35        187         83    Portugal
# 2     R. Lewandowski   31        184         80      Poland
# 3          Neymar Jr   28        175         68      Brazil
# 4       K. De Bruyne   29        181         70     Belgium
#
#              club_name             league_name  overall  potential  value_eur  \
# 0         FC Barcelona  Spain Primera Division       93         93   67500000
# 1             Juventus         Italian Serie A       92         92   46000000
# 2    FC Bayern München    German 1. Bundesliga       91         91   80000000
# 3  Paris Saint-Germain          French Ligue 1       91         91   90000000
# 4      Manchester City  English Premier League       91         91   87000000
#
#    ...  preferred_foot weak_foot skill_moves    work_rate  pace shooting  \
# 0  ...            Left         4           4   Medium/Low  85.0     92.0
# 1  ...           Right         4           5     High/Low  89.0     93.0
# 2  ...           Right         4           4  High/Medium  78.0     91.0
# 3  ...           Right         5           5  High/Medium  91.0     85.0
# 4  ...           Right         5           4    High/High  76.0     86.0
#
#    passing  dribbling  defending  physic
# 0     91.0       95.0       38.0    65.0
# 1     81.0       89.0       35.0    77.0
# 2     78.0       85.0       43.0    82.0
# 3     86.0       94.0       36.0    59.0
# 4     93.0       88.0       64.0    78.0
#
# [5 rows x 22 columns]
# Index(['name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'player_positions', 'preferred_foot', 'weak_foot', 'skill_moves',
#        'work_rate', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physic'],
#       dtype='object')
# (16666, 22)

# %%
df.columns = [c.strip().lower().replace(" ", "_") for c in df.columns]

# %%
df.columns
# Out:
# Index(['name', 'age', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'player_positions', 'preferred_foot', 'weak_foot', 'skill_moves',
#        'work_rate', 'pace', 'shooting', 'passing', 'dribbling', 'defending',
#        'physic'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# name                0
# age                 0
# height_cm           0
# weight_kg           0
# nationality         0
# club_name           0
# league_name         0
# overall             0
# potential           0
# value_eur           0
# wage_eur            0
# player_positions    0
# preferred_foot      0
# weak_foot           0
# skill_moves         0
# work_rate           0
# pace                0
# shooting            0
# passing             0
# dribbling           0
# defending           0
# physic              0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
median_value = df['value_eur'].median()
df['high_value'] = (df['value_eur'] > median_value).astype(int)

# %%
df['age_group'] = pd.cut(df['age'], bins=[15,20,25,30,35,45], labels=['15-20','21-25','26-30','31-35','36+'])

# %%
df['height_weight_ratio'] = df['height_cm'] / df['weight_kg']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['primary_position'] = df['player_positions'].apply(lambda x: x.split(',')[0])
df['primary_position_enc'] = le.fit_transform(df['primary_position'])

# %%
df = pd.get_dummies(df, columns=['preferred_foot','work_rate', 'age_group'], drop_first=True)

# %%
Q1 = df['value_eur'].quantile(0.25)
Q3 = df['value_eur'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df = df[(df['value_eur'] >= lower_bound) & (df['value_eur'] <= upper_bound)]

# %%
df.head()
# Out:
#               name  age  height_cm  weight_kg nationality  \
# 265           Pepe   37        188         81    Portugal
# 377    B. Ivanović   36        185         91      Serbia
# 500       Quaresma   36        175         67    Portugal
# 501  J. Mascherano   36        174         73   Argentina
# 521      M. Parolo   35        184         75       Italy
#
#                    club_name                 league_name  overall  potential  \
# 265                 FC Porto  Portuguese Liga ZON SAGRES       81         81
# 377     West Bromwich Albion      English Premier League       80         80
# 500        Vitória Guimarães  Portuguese Liga ZON SAGRES       79         79
# 501  Estudiantes de La Plata  Argentina Primera División       79         79
# 521                    Lazio             Italian Serie A       79         79
#
#      value_eur  ...  work_rate_Low/High work_rate_Low/Low  \
# 265    3600000  ...               False             False
# 377    3000000  ...               False             False
# 500    4200000  ...               False             False
# 501    2700000  ...                True             False
# 521    4000000  ...               False             False
#
#      work_rate_Low/Medium  work_rate_Medium/High  work_rate_Medium/Low  \
# 265                 False                   True                 False
# 377                 False                  False                 False
# 500                 False                  False                 False
# 501                 False                  False                 False
# 521                 False                  False                 False
#
#      work_rate_Medium/Medium  age_group_21-25  age_group_26-30  \
# 265                    False            False            False
# 377                    False            False            False
# 500                    False            False            False
# 501                    False            False            False
# 521                    False            False            False
#
#      age_group_31-35  age_group_36+
# 265            False           True
# 377            False           True
# 500            False           True
# 501            False           True
# 521             True          False
#
# [5 rows x 37 columns]

# %%
df.to_csv("data/fifa_players_preprocessed.csv", index=False)
